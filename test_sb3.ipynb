# %%
import gymnasium as gym
from stable_baselines3 import SAC, A2C
from sb3_contrib import TQC

env = gym.make("HalfCheetah", render_mode="rgb_array")

model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=20_000)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# /Users/pradyumnaym/.local/share/virtualenvs/RL_project-HQinAoks/lib/python3.10/site-packages/gymnasium/envs/registration.py:525: UserWarning: WARN: Using the latest versioned environment `HalfCheetah-v5` instead of the unversioned environment `HalfCheetah`.
#   logger.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | time/                 |          |
# |    fps                | 2307     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -8.52    |
# |    explained_variance | -0.0919  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -11.2    |
# |    std                | 1        |
# |    value_loss         | 2.34     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -360     |
# | time/                 |          |
# |    fps                | 2268     |
# |    iterations         | 200      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -8.54    |
# |    explained_variance | -5.66    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.7      |
# |    std                | 1.01     |
# |    value_loss         | 1.07     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -360     |
# | time/                 |          |
# |    fps                | 2342     |
# |    iterations         | 300      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -8.55    |
# |    explained_variance | -4.03    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -18.5    |
# |    std                | 1.01     |
# |    value_loss         | 4.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -376     |
# | time/                 |          |
# |    fps                | 2380     |
# |    iterations         | 400      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -8.56    |
# |    explained_variance | -0.492   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -12      |
# |    std                | 1.01     |
# |    value_loss         | 4.51     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -376     |
# | time/                 |          |
# |    fps                | 2416     |
# |    iterations         | 500      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -8.58    |
# |    explained_variance | -0.358   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -2.39    |
# |    std                | 1.01     |
# |    value_loss         | 1.07     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -393     |
# | time/                 |          |
# |    fps                | 2433     |
# |    iterations         | 600      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -8.55    |
# |    explained_variance | -2.02    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -8.23    |
# |    std                | 1.01     |
# |    value_loss         | 1.12     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -393     |
# | time/                 |          |
# |    fps                | 2442     |
# |    iterations         | 700      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -8.53    |
# |    explained_variance | 0.0433   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 2.93     |
# |    std                | 1        |
# |    value_loss         | 0.302    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -388     |
# | time/                 |          |
# |    fps                | 2445     |
# |    iterations         | 800      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -8.54    |
# |    explained_variance | 0.189    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -10.3    |
# |    std                | 1.01     |
# |    value_loss         | 2.05     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -388     |
# | time/                 |          |
# |    fps                | 2452     |
# |    iterations         | 900      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -8.55    |
# |    explained_variance | -0.555   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 18.2     |
# |    std                | 1.01     |
# |    value_loss         | 6.89     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -399     |
# | time/                 |          |
# |    fps                | 2468     |
# |    iterations         | 1000     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -8.56    |
# |    explained_variance | 0.228    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -5.35    |
# |    std                | 1.01     |
# |    value_loss         | 0.93     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -399     |
# | time/                 |          |
# |    fps                | 2481     |
# |    iterations         | 1100     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -8.56    |
# |    explained_variance | -77.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 31.9     |
# |    std                | 1.01     |
# |    value_loss         | 22.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -378     |
# | time/                 |          |
# |    fps                | 2494     |
# |    iterations         | 1200     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -8.54    |
# |    explained_variance | -0.0112  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -29.5    |
# |    std                | 1        |
# |    value_loss         | 13.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -378     |
# | time/                 |          |
# |    fps                | 2504     |
# |    iterations         | 1300     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -8.54    |
# |    explained_variance | -3.35    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 6.86     |
# |    std                | 1        |
# |    value_loss         | 1.05     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -371     |
# | time/                 |          |
# |    fps                | 2507     |
# |    iterations         | 1400     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -8.54    |
# |    explained_variance | -0.00594 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -6.87    |
# |    std                | 1.01     |
# |    value_loss         | 1.35     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -371     |
# | time/                 |          |
# |    fps                | 2513     |
# |    iterations         | 1500     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -8.55    |
# |    explained_variance | 0.0321   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -1.34    |
# |    std                | 1.01     |
# |    value_loss         | 0.643    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -369     |
# | time/                 |          |
# |    fps                | 2516     |
# |    iterations         | 1600     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -8.55    |
# |    explained_variance | 0.124    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.0752  |
# |    std                | 1.01     |
# |    value_loss         | 0.457    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -369     |
# | time/                 |          |
# |    fps                | 2523     |
# |    iterations         | 1700     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -8.56    |
# |    explained_variance | -0.0425  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -10.6    |
# |    std                | 1.01     |
# |    value_loss         | 2.37     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -366     |
# | time/                 |          |
# |    fps                | 2526     |
# |    iterations         | 1800     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -8.59    |
# |    explained_variance | 0.0708   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 7.52     |
# |    std                | 1.01     |
# |    value_loss         | 0.99     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -366     |
# | time/                 |          |
# |    fps                | 2527     |
# |    iterations         | 1900     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -8.57    |
# |    explained_variance | -0.0288  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.822    |
# |    std                | 1.01     |
# |    value_loss         | 1.32     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -367     |
# | time/                 |          |
# |    fps                | 2532     |
# |    iterations         | 2000     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -8.55    |
# |    explained_variance | -0.0437  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 9.83     |
# |    std                | 1.01     |
# |    value_loss         | 1.37     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -367     |
# | time/                 |          |
# |    fps                | 2536     |
# |    iterations         | 2100     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -8.54    |
# |    explained_variance | 0.11     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -2.89    |
# |    std                | 1        |
# |    value_loss         | 0.222    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -363     |
# | time/                 |          |
# |    fps                | 2537     |
# |    iterations         | 2200     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -8.56    |
# |    explained_variance | 0.429    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -7.74    |
# |    std                | 1.01     |
# |    value_loss         | 1.54     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -363     |
# | time/                 |          |
# |    fps                | 2541     |
# |    iterations         | 2300     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -8.57    |
# |    explained_variance | -0.232   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -4.35    |
# |    std                | 1.01     |
# |    value_loss         | 0.704    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -372     |
# | time/                 |          |
# |    fps                | 2543     |
# |    iterations         | 2400     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -8.58    |
# |    explained_variance | -2.12    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -24.2    |
# |    std                | 1.01     |
# |    value_loss         | 9.77     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -372     |
# | time/                 |          |
# |    fps                | 2545     |
# |    iterations         | 2500     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -8.54    |
# |    explained_variance | -0.00749 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 5.48     |
# |    std                | 1        |
# |    value_loss         | 0.491    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -372     |
# | time/                 |          |
# |    fps                | 2547     |
# |    iterations         | 2600     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -8.52    |
# |    explained_variance | 0.0466   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -12.7    |
# |    std                | 1        |
# |    value_loss         | 3.08     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -372     |
# | time/                 |          |
# |    fps                | 2547     |
# |    iterations         | 2700     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -8.52    |
# |    explained_variance | 0.0206   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.765   |
# |    std                | 1        |
# |    value_loss         | 0.478    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -377     |
# | time/                 |          |
# |    fps                | 2547     |
# |    iterations         | 2800     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -8.47    |
# |    explained_variance | 0.0399   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -2.45    |
# |    std                | 0.993    |
# |    value_loss         | 0.115    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -377     |
# | time/                 |          |
# |    fps                | 2535     |
# |    iterations         | 2900     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -8.45    |
# |    explained_variance | 0.0671   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -4.46    |
# |    std                | 0.99     |
# |    value_loss         | 0.397    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -373     |
# | time/                 |          |
# |    fps                | 2536     |
# |    iterations         | 3000     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -8.45    |
# |    explained_variance | -0.0863  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -19.3    |
# |    std                | 0.989    |
# |    value_loss         | 5.15     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -373     |
# | time/                 |          |
# |    fps                | 2537     |
# |    iterations         | 3100     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -8.42    |
# |    explained_variance | -0.301   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 17.5     |
# |    std                | 0.984    |
# |    value_loss         | 5.33     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -371     |
# | time/                 |          |
# |    fps                | 2539     |
# |    iterations         | 3200     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -8.39    |
# |    explained_variance | 0.00268  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -3.61    |
# |    std                | 0.98     |
# |    value_loss         | 0.373    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -371     |
# | time/                 |          |
# |    fps                | 2542     |
# |    iterations         | 3300     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -8.37    |
# |    explained_variance | 0.789    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 10.6     |
# |    std                | 0.976    |
# |    value_loss         | 1.77     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -369     |
# | time/                 |          |
# |    fps                | 2544     |
# |    iterations         | 3400     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -8.35    |
# |    explained_variance | 0.484    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -1.94    |
# |    std                | 0.973    |
# |    value_loss         | 0.17     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -369     |
# | time/                 |          |
# |    fps                | 2547     |
# |    iterations         | 3500     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -8.35    |
# |    explained_variance | 0.545    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 14.1     |
# |    std                | 0.973    |
# |    value_loss         | 3.02     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -375     |
# | time/                 |          |
# |    fps                | 2549     |
# |    iterations         | 3600     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -8.36    |
# |    explained_variance | -0.167   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -3.83    |
# |    std                | 0.975    |
# |    value_loss         | 2.83     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -375     |
# | time/                 |          |
# |    fps                | 2552     |
# |    iterations         | 3700     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -8.34    |
# |    explained_variance | 0.271    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -10.5    |
# |    std                | 0.972    |
# |    value_loss         | 3.74     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -378     |
# | time/                 |          |
# |    fps                | 2554     |
# |    iterations         | 3800     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -8.34    |
# |    explained_variance | 0.366    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -1.38    |
# |    std                | 0.972    |
# |    value_loss         | 0.159    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -378     |
# | time/                 |          |
# |    fps                | 2555     |
# |    iterations         | 3900     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -8.36    |
# |    explained_variance | 0.908    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 12.8     |
# |    std                | 0.975    |
# |    value_loss         | 3.02     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | -376     |
# | time/                 |          |
# |    fps                | 2557     |
# |    iterations         | 4000     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -8.34    |
# |    explained_variance | 0.462    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 3.09     |
# |    std                | 0.971    |
# |    value_loss         | 0.243    |
# ------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 15
#      13 action, _state = model.predict(obs, deterministic=True)
#      14 obs, reward, done, info = vec_env.step(action)
# ---> 15 vec_env.render("human")
#
# File ~/.local/share/virtualenvs/RL_project-HQinAoks/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:103, in DummyVecEnv.render(self, mode)
#      96 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
#      97     """
#      98     Gym environment rendering. If there are multiple environments then
#      99     they are tiled together in one image via ``BaseVecEnv.render()``.
#     100
#     101     :param mode: The rendering type.
#     102     """
# --> 103     return super().render(mode=mode)
#
# File ~/.local/share/virtualenvs/RL_project-HQinAoks/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:264, in VecEnv.render(self, mode)
#     261     import cv2
#     263     cv2.imshow("vecenv", bigimg[:, :, ::-1])
# --> 264     cv2.waitKey(1)
#     265 else:
#     266     return bigimg
#
# KeyboardInterrupt:

# %%
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 6
#       4 action, _state = model.predict(obs, deterministic=True)
#       5 obs, reward, done, info = vec_env.step(action)
# ----> 6 vec_env.render("human")
#
# File ~/.local/share/virtualenvs/RL_project-HQinAoks/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:103, in DummyVecEnv.render(self, mode)
#      96 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
#      97     """
#      98     Gym environment rendering. If there are multiple environments then
#      99     they are tiled together in one image via ``BaseVecEnv.render()``.
#     100
#     101     :param mode: The rendering type.
#     102     """
# --> 103     return super().render(mode=mode)
#
# File ~/.local/share/virtualenvs/RL_project-HQinAoks/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:264, in VecEnv.render(self, mode)
#     261     import cv2
#     263     cv2.imshow("vecenv", bigimg[:, :, ::-1])
# --> 264     cv2.waitKey(1)
#     265 else:
#     266     return bigimg
#
# KeyboardInterrupt:
